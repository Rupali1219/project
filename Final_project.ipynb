# %%
import json

class Restraurent:
  def __init__(self):
    self.foods={}
    self.personal_information={}
    self.food_id=len(self.foods)

  def food_items(self):
    self.name=input("Enter food name") 
    self.quantity=int(input("Enter food quantity"))
    self.price=int(input("Enter food price :Rs."))
    self.discount=int(input("Enter food discount :Rs."))
    self.stock=int(input("Enter food stock :kg"))
    self.item={"name":self.name,"quantity":self.quantity,"price":self.price,"discount":self.discount,"stock":self.stock}
    self.food_id=len(self.foods)+1
    self.foods[self.food_id]=self.item
    print(self.foods)
    with open("food_items.json","w")as f:
      json.dump(self.foods,f)
    print("item added successfully")
  
  def remove_food_items(self):
    del self.foods[int(input("Enter the food_id which you want to delete"))]
    with open("food_items.json","w")as f:
      json.dump(self.foods,f)
    print("Remaining items are",self.foods)
  def edit_food_items(self):
    f_id=int(input("Enter the food_id you want to update"))
    for i in self.foods[f_id]:
      self.foods[f_id][i]=input("Enter the data that you want to update")
    with open("food_items.json","w")as f:
      json.dump(self.foods,f)
    print("food_item updated successfully")
  def view_food_items(self):
    print("list of all food items")
    for i in self.foods:
      print("food_id :",i,"\n")
      for j in self.foods[i]:
        print(j,":",self.foods[i][j]) 
      
  def Registration(self):
    self.Fullname=input("Enter your Fullname") 
    self.phone_number=int(input("Enter your phone_number"))
    self.email=input("Enter your email")
    self.user_password=input("Enter your password")
    self.address=input("Enter your address")
    self.username={"Fullname":self.Fullname,"phone_number":self.phone_number,"email":self.email,"address":self.address,"user_password":self.user_password}
    self.foods[self.food_id]=self.username
    print(self.foods)
    with open("food_username.json","w")as f:
      json.dump(self.personal_information,f)
    print("Registration successfully")

  def login(self):
    while True:
      user_email=input("Enter your email")
      password=input("Enter your password")
      if user_email== self.email:
        if password== self.user_password:
          print("you have logged in successfully")
          break
        else:
          print("incorrect details")
      else:
        print("incorrect credentials")
    
  def place_order(self):
    x=[]
    x1="Tandoori chicken","vegan burger","Truffle cake"
    x.append(x1)
    print(x)
    order=int(input("Which order you want to place?"))
  
    if order==1:
      print("Tandoori chicken")
    elif order==2:
      print("Vegan Burger")
    elif order==3:
      print("Truffle cake")
    else:
      print("Please give currently available order") 
    
         
  def update_details(self): 
    res=Restraurent
    while True:
      print("Welcome to my Restraurent")
      print("why you want to login as a \n1.Admin \n2.User \n3.Exit ")   
      user_input=int(input("Enter your choice of login"))
      if user_input==1:  
        print("welcome to the admin section")
        print("enter the details you want to update in admin section \n1.Admin \n2.edit \n3.remove \n4.view")
        user1=int(input("Enter number which you want to update"))
        if user1==1: 
          print('Go to admin section')
        if user1==2:
          print("Go to edit section")
        if user1==3:
          print("Go to remove section")
        if user1==4:
          print("Go to view section") 
          
      if user_input==2:
        print("welcome to the user section")
        print("enter the details you want to update in user section \n1.view \n2.edit \n3.delete ")
        user2=int(input("Enter number which you want to update"))
        if user2==1:
          print('View your profile')
        if user2==2:
          print("Edit your profile")
        if user2==3:
          print("Delete your profilr")
        
      if user_input==3: 
        print("you can exit")
        break
    else:
      print("Please enter vaild number")
   
     
x=Restraurent()
x.food_items()
x.food_items()
x.food_items()
x.remove_food_items()
x.edit_food_items()
x.view_food_items()
x.Registration()
x.login()
x.place_order()
x.update_details()
# Out:
# Enter food name maggie
# Enter food quantity 10
# Enter food price :Rs.25
# Enter food discount :Rs.10
# Enter food stock :kg30
# {1: {'name': ' maggie', 'quantity': 10, 'price': 25, 'discount': 10, 'stock': 30}}
# item added successfully
# Enter food name pizza
# Enter food quantity 50
# Enter food price :Rs. 150
# Enter food discount :Rs.20
# Enter food stock :kg 20
# {1: {'name': ' maggie', 'quantity': 10, 'price': 25, 'discount': 10, 'stock': 30}, 2: {'name': ' pizza', 'quantity': 50, 'price': 150, 'discount': 20, 'stock': 20}}
# item added successfully
# Enter food name samosa
# Enter food quantity 100
# Enter food price :Rs.20
# Enter food discount :Rs.2
# Enter food stock :kg 30
# {1: {'name': ' maggie', 'quantity': 10, 'price': 25, 'discount': 10, 'stock': 30}, 2: {'name': ' pizza', 'quantity': 50, 'price': 150, 'discount': 20, 'stock': 20}, 3: {'name': ' samosa', 'quantity': 100, 'price': 20, 'discount': 2, 'stock': 30}}
# item added successfully
# ...
